# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitsaxena2512-gif/traveltemplate/blob/main/transcribe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('welcome to google colab')
# Out:
# welcome to google colab
